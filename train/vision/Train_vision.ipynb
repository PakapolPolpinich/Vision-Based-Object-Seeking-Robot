# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="data.yaml",
    epochs=100,
    imgsz=512,
    batch=8,
    lr0=0.01, #learning rate
    device=0,
    workers=0,
    cache=False,
    project="result_vision",
    name="Result",
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.12 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.11  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO("runs/detect/result_vision/Result/weights/best.pt")
results = model.predict(source=0, show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x512 (no detections), 23.9ms
# 0: 384x512 (no detections), 8.9ms
# 0: 384x512 (no detections), 9.9ms
# 0: 384x512 (no detections), 11.2ms
# 0: 384x512 (no detections), 9.1ms
# 0: 384x512 (no detections), 11.8ms
# 0: 384x512 (no detections), 11.2ms
# WARNING Waiting for stream 0
# 0: 384x512 (no detections), 10.3ms
# 0: 384x512 (no detections), 9.4ms
# ...
